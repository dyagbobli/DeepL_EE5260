# %% [markdown]
# ### CustomAlexNet Accuracy = 59.98%

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Sample data from the Excel sheet provided
epochs = np.arange(1, 16)  # Epochs from 1 to 15
train_loss = np.array([3.786, 2.6331, 2.0296, 1.6517, 1.3703, 1.1275, 0.8948, 0.6838, 0.4966, 0.3589,
                       0.2695, 0.2291, 0.1839, 0.1622, 0.1487])
val_loss = np.array([3.1969, 2.4201, 1.9168, 1.6698, 1.557, 1.5216, 1.4612, 1.4899, 1.6868, 1.6936,
                     1.7024, 1.8079, 1.9359, 2.0046, 1.975])

# Plotting loss curves
plt.figure(figsize=(5, 4))
plt.plot(epochs, train_loss, 'r', label='Train Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
#plt.axhline(y=1.5, color='k', linestyle='--', label='Test Loss')

# Adding labels and title
plt.title('Loss Curve')
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()


# Sample data for accuracy
train_accuracy = np.array([11.31, 30.96, 44.43, 53.19, 60.18, 66.89, 72.69, 78.71, 84.28, 88.55,
                           91.49, 92.71, 94.14, 94.97, 95.26])
val_accuracy = np.array([20.25, 36.85, 47.27, 52.4, 55.75, 58.85, 60.08, 60.65, 58.75, 59.25,
                         60.95, 59.15, 59.83, 59.67, 59.77])

# Plotting accuracy curves
plt.figure(figsize=(5, 4))
plt.plot(epochs, train_accuracy, 'g', label='Train Accuracy')
plt.plot(epochs, val_accuracy, 'm', label='Validation Accuracy')
#plt.axhline(y=75, color='purple', linestyle='--', label='Test Accuracy')

# Adding labels and title
plt.title('Accuracy Curve')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ### CustomDenseNet Accuracy = 70.30%

# %%
# Sample data from the Excel sheet provided
epochs = np.arange(1, 16)  # Epochs from 1 to 15
train_loss = np.array([2.3712, 1.4755, 1.152, 0.9596, 0.7725, 0.6384, 0.5124, 0.433, 0.3487, 
                       0.3021, 0.2541, 0.2394, 0.2127, 0.1898, 0.1844])
val_loss = np.array([1.8098, 1.4003, 1.315, 1.2538, 1.1979, 1.1648, 1.1885, 1.2879, 1.267, 
                     1.3795, 1.2898, 1.3347, 1.3828, 1.3835, 1.4531])

# Plotting loss curves
plt.figure(figsize=(5, 4))
plt.plot(epochs, train_loss, 'r', label='Train Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
#plt.axhline(y=1.5, color='k', linestyle='--', label='Test Loss')

# Adding labels and title
plt.title('Loss Curve')
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()


# Sample data for accuracy
train_accuracy = np.array([37.76, 57.57, 66.14, 71.2, 76.33, 80, 83.67, 86.09, 88.68, 
                           90.14, 91.93, 92.01, 92.93, 93.71, 93.91])
val_accuracy = np.array([49.73, 59.77, 62.65, 64.72, 66.65, 67.67, 68.8, 67.53, 69.12, 
                         68.35, 70.3, 69.42, 70.38, 69.7, 69.6])

# Plotting accuracy curves
plt.figure(figsize=(5, 4))
plt.plot(epochs, train_accuracy, 'g', label='Train Accuracy')
plt.plot(epochs, val_accuracy, 'm', label='Validation Accuracy')
#plt.axhline(y=75, color='purple', linestyle='--', label='Test Accuracy')

# Adding labels and title
plt.title('Accuracy Curve')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ### CustomResNet Accuracy = 24.88%

# %%
# Sample data from the Excel sheet provided
epochs = np.arange(1, 16)  # Epochs from 1 to 15
train_loss = np.array([4.3857, 4.1394, 3.9237, 3.7423, 3.6027, 3.4955, 3.4078, 3.3316, 3.2589, 3.2067,
                       3.1463, 3.1113, 3.0646, 2.9991, 2.9635])
val_loss = np.array([4.1813, 3.9698, 3.7558, 3.5828, 3.5653, 3.4355, 3.3205, 3.2737, 3.2469, 3.1779,
                     3.1234, 3.2013, 3.0909, 3.0843, 3.1289])


# Plotting loss curves
plt.figure(figsize=(5, 4))
plt.plot(epochs, train_loss, 'r', label='Train Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
#plt.axhline(y=1.5, color='k', linestyle='--', label='Test Loss')

# Adding labels and title
plt.title('Loss Curve')
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()


# Sample data for accuracy
train_accuracy = np.array([3.1, 6.14, 9.31, 11.97, 14.27, 16.28, 18.03, 19.55, 20.37, 21.56,
                           23.1, 23.69, 24.35, 25.69, 26.24])
val_accuracy = np.array([4.95, 8.15, 12.18, 14.62, 15.22, 17.55, 20.62, 20.8, 22.73, 23.5,
                         25.23, 21.85, 24.45, 24.48, 23.45])

# Plotting accuracy curves
plt.figure(figsize=(5, 4))
plt.plot(epochs, train_accuracy, 'g', label='Train Accuracy')
plt.plot(epochs, val_accuracy, 'm', label='Validation Accuracy')
#plt.axhline(y=75, color='purple', linestyle='--', label='Test Accuracy')

# Adding labels and title
plt.title('Accuracy Curve')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ### CustomAlexNet_v1 Accuracy = 57.94%

# %%
# Sample data from the Excel sheet provided
epochs = np.arange(1, 16)  # Epochs from 1 to 15
train_loss = np.array([4.2783, 3.7238, 3.2308, 2.8787, 2.6062, 2.3951, 2.2150, 2.0667, 1.9356, 1.8339,
                       1.7352, 1.6419, 1.5628, 1.4906, 1.4095])
val_loss = np.array([4.0135, 3.4534, 3.0770, 2.7278, 2.6373, 2.3633, 2.1865, 2.1168, 2.0753, 1.8897,
                     1.8840, 1.8106, 1.7878, 1.7462, 1.6709])


# Plotting loss curves
plt.figure(figsize=(5, 4))
plt.plot(epochs, train_loss, 'r', label='Train Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
#plt.axhline(y=1.5, color='k', linestyle='--', label='Test Loss')

# Adding labels and title
plt.title('Loss Curve')
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()


# Sample data for accuracy
train_accuracy = np.array([4.7, 12.27, 20.49, 27.39, 32.88, 37.42, 41.27, 44.66, 47.73, 50.12,
                           52.31, 54.42, 56.65, 58.19, 60.09])
val_accuracy = np.array([8.65, 16.32, 23.05, 30.27, 32.48, 38.3, 41.9, 44.83, 44.58, 48.38,
                         49.7, 51.17, 51.48, 52.52, 54.9])

# Plotting accuracy curves
plt.figure(figsize=(5, 4))
plt.plot(epochs, train_accuracy, 'g', label='Train Accuracy')
plt.plot(epochs, val_accuracy, 'm', label='Validation Accuracy')
#plt.axhline(y=75, color='purple', linestyle='--', label='Test Accuracy')

# Adding labels and title
plt.title('Accuracy Curve')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ### CustomDenseNet_v1 Accuracy = 71.74%

# %%
# Sample data from the Excel sheet provided
epochs = np.arange(1, 16)  # Epochs from 1 to 15
train_loss = np.array([3.242, 2.0977, 1.7304, 1.518, 1.3531, 1.23, 1.138, 1.0523, 0.9714, 0.9044,
                       0.8419, 0.7748, 0.728, 0.686, 0.6453])
val_loss = np.array([2.4264, 1.9048, 1.7011, 1.6975, 1.4312, 1.3573, 1.3293, 1.2816, 1.2546, 1.2297,
                     1.2091, 1.2342, 1.2611, 1.2609, 1.1662])

# Plotting loss curves
plt.figure(figsize=(5, 4))
plt.plot(epochs, train_loss, 'r', label='Train Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
#plt.axhline(y=1.5, color='k', linestyle='--', label='Test Loss')

# Adding labels and title
plt.title('Loss Curve')
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()


# Sample data for accuracy
train_accuracy = np.array([20.86, 43.1, 51.95, 57.24, 61.16, 64.66, 66.64, 68.99, 71.24, 72.9,
                           74.54, 76.33, 77.5, 78.76, 79.98])
val_accuracy = np.array([35.92, 47.8, 53.08, 54.02, 59.2, 61.83, 62.48, 64.3, 64.72, 65.25,
                         66.45, 66.33, 66.47, 67.03, 69.05])

# Plotting accuracy curves
plt.figure(figsize=(5, 4))
plt.plot(epochs, train_accuracy, 'g', label='Train Accuracy')
plt.plot(epochs, val_accuracy, 'm', label='Validation Accuracy')
#plt.axhline(y=75, color='purple', linestyle='--', label='Test Accuracy')

# Adding labels and title
plt.title('Accuracy Curve')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ### CustomResNet_v1 Accuracy = 1%

# %%
# Sample data from the Excel sheet provided
epochs = np.arange(1, 16)  # Epochs from 1 to 15
train_loss = np.array([4.6091, 4.6069, 4.6269, 4.6064, 4.6063, 4.6063, 4.6062, 4.6063, 4.6063, 4.6062,
                       4.6063, 4.6063, 4.6060, 4.6063, 4.6061])
val_loss = np.array([4.6083, 4.6069, 4.6065, 4.6070, 4.6069, 4.6073, 4.6076, 4.6072, 4.6076, 4.6084,
                     4.6074, 4.6074, 4.6076, 4.6072, 4.6072])

# Plotting loss curves
plt.figure(figsize=(5, 4))
plt.plot(epochs, train_loss, 'r', label='Train Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
#plt.axhline(y=1.5, color='k', linestyle='--', label='Test Loss')

# Adding labels and title
plt.title('Loss Curve')
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()


# Sample data for accuracy
train_accuracy = np.array([0.88, 0.92, 1.04, 0.95, 0.99, 0.95, 0.99, 0.92, 1.05, 0.93,
                           0.94, 1.04, 0.99, 1.01, 0.94])
val_accuracy = np.array([0.8, 0.93, 1.02, 0.85, 0.85, 0.85, 0.65, 0.85, 1.02, 1.02,
                         1.02, 0.85, 0.85, 0.65, 0.95])

# Plotting accuracy curves
plt.figure(figsize=(5, 4))
plt.plot(epochs, train_accuracy, 'g', label='Train Accuracy')
plt.plot(epochs, val_accuracy, 'm', label='Validation Accuracy')
#plt.axhline(y=75, color='purple', linestyle='--', label='Test Accuracy')

# Adding labels and title
plt.title('Accuracy Curve')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ### CustomAlexNet_v2 Accuracy = 66.64%

# %% [markdown]
# import numpy as np
#
# epochs = np.arange(1, 31)  # Epochs from 1 to 30

# %%
# Sample data from the Excel sheet provided
epochs = np.arange(1, 31)  # Epochs from 1 to 15
train_loss = np.array([
    4.2152, 3.561, 3.0466, 2.6745, 2.3973, 2.1688, 2.0035, 1.8491, 1.726, 1.6129,
    1.5133, 1.414, 1.3391, 1.2735, 1.1967, 1.1375, 1.0767, 1.0255, 0.9691, 0.9182,
    0.8654, 0.8249, 0.7867, 0.7401, 0.7089, 0.6772, 0.6386, 0.6079, 0.5791, 0.5437
])

val_loss = np.array([
    3.784, 3.3313, 3.0297, 2.6675, 2.2543, 2.1611, 2.0435, 1.9038, 1.9335, 1.697,
    1.6895, 1.6619, 1.6041, 1.5523, 1.5801, 1.4849, 1.4564, 1.4739, 1.3994, 1.5054,
    1.5074, 1.4466, 1.432, 1.4244, 1.425, 1.4496, 1.5089, 1.4013, 1.3947, 1.4326
])

# Plotting loss curves
plt.figure(figsize=(5, 4))
plt.plot(epochs, train_loss, 'r', label='Train Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
#plt.axhline(y=1.5, color='k', linestyle='--', label='Test Loss')

# Adding labels and title
plt.title('Loss Curve')
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()


# Sample data for accuracy
train_accuracy = np.array([
    4.93, 14.42, 23.77, 30.89, 37.05, 42.25, 45.84, 49.36, 52.26, 54.98,
    57.41, 60.05, 62.14, 63.05, 65.39, 66.68, 68.26, 69.86, 71.38, 72.61,
    73.96, 75.09, 76.16, 77.48, 78.11, 79.45, 80.16, 81.18, 82.07, 83.12
])

val_accuracy = np.array([
    9.9, 19.3, 24.15, 31.35, 40.48, 41.65, 45.33, 48.23, 48.45, 52.9,
    53.65, 55.12, 55.62, 57.3, 57.75, 58.85, 60.0, 59.92, 61.48, 59.75,
    60.67, 61.52, 62.12, 62.58, 63.42, 62.67, 61.55, 63.5, 64.22, 64.17
])

# Plotting accuracy curves
plt.figure(figsize=(5, 4))
plt.plot(epochs, train_accuracy, 'g', label='Train Accuracy')
plt.plot(epochs, val_accuracy, 'm', label='Validation Accuracy')
#plt.axhline(y=75, color='purple', linestyle='--', label='Test Accuracy')

# Adding labels and title
plt.title('Accuracy Curve')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ### CustomDenseNet_v2 Accuracy = 72.34%

# %%
# Sample data from the Excel sheet provided
epochs = np.arange(1, 31)  # Epochs from 1 to 15

train_loss = np.array([
    2.8976, 1.9379, 1.6237, 1.4233, 1.2828, 1.1819, 1.0845, 0.9952, 0.9181, 0.8549,
    0.7852, 0.7382, 0.6815, 0.6423, 0.5945, 0.5611, 0.5313, 0.4829, 0.4543, 0.4441,
    0.4249, 0.3815, 0.3731, 0.3466, 0.3289, 0.32,   0.3115, 0.2988, 0.2852, 0.2738
])

val_loss = np.array([
    2.2056, 1.7601, 1.6437, 1.4743, 1.3995, 1.3194, 1.2948, 1.2525, 1.2035, 1.2355,
    1.1593, 1.1706, 1.1864, 1.1743, 1.1994, 1.2763, 1.2108, 1.2864, 1.2749, 1.1973,
    1.2159, 1.2739, 1.2903, 1.3284, 1.3276, 1.3402, 1.3122, 1.3486, 1.3345, 1.3771
])



train_accuracy = np.array([
    27.58, 47.08, 54.28, 59.67, 63.03, 65.64, 68.07, 70.32, 72.51, 74.38,
    76.14, 77.41, 78.92, 80.08, 81.44, 82.33, 83.12, 84.67, 85.42, 85.83,
    86.23, 87.54, 87.89, 88.74, 89.34, 89.69, 89.86, 90.19, 90.62, 91.11
])

val_accuracy = np.array([
    40.77, 50.45, 54.33, 58.00, 60.52, 62.90, 64.20, 65.62, 66.33, 66.33,
    68.33, 68.12, 68.70, 68.45, 68.42, 67.12, 69.10, 67.65, 69.65, 69.72,
    70.53, 69.20, 69.47, 69.53, 69.65, 69.33, 70.65, 70.40, 69.38, 69.03
])

# Plotting loss curves
plt.figure(figsize=(5, 4))
plt.plot(epochs, train_loss, 'r', label='Train Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
#plt.axhline(y=1.5, color='k', linestyle='--', label='Test Loss')

# Adding labels and title
plt.title('Loss Curve')
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()


# Sample data for accuracy


# Plotting accuracy curves
plt.figure(figsize=(5, 4))
plt.plot(epochs, train_accuracy, 'g', label='Train Accuracy')
plt.plot(epochs, val_accuracy, 'm', label='Validation Accuracy')
#plt.axhline(y=75, color='purple', linestyle='--', label='Test Accuracy')

# Adding labels and title
plt.title('Accuracy Curve')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy (%)')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()
